# %%
import pandas as pd

# %%
weather = pd.read_csv("./weatherdat.csv", usecols = [1,2,3,4,5,6,7,8])
weather
# Out:
#                         City Country   Latitude   Longitude  Temperature  \
# 0                     agadez      ne  16.583131    8.048942        95.00
# 1                  jamestown      sh -26.442263   -2.653680        69.34
# 2                    ushuaia      ar -82.349391  -53.302561        30.20
# 3                yellowknife      ca  83.352442 -102.249792        53.19
# 4                    emerald      au -23.123143  146.557092        71.19
# 5                      kapaa      us  21.794101 -158.970869        81.34
# 6                   zhaoyuan      cn  45.598122  124.854615        71.86
# 7                new norfolk      au -56.959007  137.091062        52.56
# 8                   hermanus      za -53.906017    8.722280        58.98
# 9                 butaritari      ki  12.953561  162.846265        84.46
# 10                      hilo      us  13.504610 -150.681269        79.48
# 11        havre-saint-pierre      ca  55.722352  -63.531292        53.60
# ...

# %%
print(weather.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloud Cover</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>agadez</td>
#       <td>ne</td>
#       <td>16.583131</td>
#       <td>8.048942</td>
#       <td>95.00</td>
#       <td>17</td>
#       <td>1</td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>jamestown</td>
#       <td>sh</td>
#       <td>-26.442263</td>
#       <td>-2.653680</td>
#       <td>69.34</td>
#       <td>73</td>
#       <td>100</td>
#       <td>19.77</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ushuaia</td>
#       <td>ar</td>
#       <td>-82.349391</td>
#       <td>-53.302561</td>
#       <td>30.20</td>
#       <td>80</td>
# ...
